# %%
import numpy as np
import pandas as pd


# Monkey patch numpy to add np.float_ as an alias to np.float64
np.float_ = np.float64

# Now import Prophet
from prophet import Prophet
from prophet.plot import plot_plotly, plot_components_plotly

# %%
train_path = '../data/clean/train.csv'
df = pd.read_csv(train_path)
df.head()
# Out:
#          date   open   high    low  close      volume  change  changePercent  \
# 0  2019-06-28  23.45  23.45  22.67  22.78  47733000.0   -0.67        -2.8600
# 1  2019-06-29  23.45  23.45  22.67  22.78  47733000.0   -0.67        -2.8600
# 2  2019-06-30  23.45  23.45  22.67  22.78  47733000.0   -0.67        -2.8600
# 3  2019-07-01  23.60  23.94  22.97  23.38  12103000.0   -0.22        -0.9322
# 4  2019-07-02  22.91  23.44  22.58  23.42  13069000.0    0.51         2.2300
#
#     vwap        rsi         adx  standardDeviation  ratingScore
# 0  22.97  58.965646  102.767512           0.898712            4
# 1  22.97  58.965646  102.767512           0.898712            4
# 2  22.97  58.965646  102.767512           0.898712            4
# 3  23.43  62.959665   99.734268           0.877744            4
# 4  23.15  63.216708   96.577138           0.883491            4

# %%
df['ds'] = pd.to_datetime(df.date)
df['y'] = df.close

df
# Out:
#             date   open   high    low  close      volume  change  \
# 0     2019-06-28  23.45  23.45  22.67  22.78  47733000.0  -0.670
# 1     2019-06-29  23.45  23.45  22.67  22.78  47733000.0  -0.670
# 2     2019-06-30  23.45  23.45  22.67  22.78  47733000.0  -0.670
# 3     2019-07-01  23.60  23.94  22.97  23.38  12103000.0  -0.220
# 4     2019-07-02  22.91  23.44  22.58  23.42  13069000.0   0.510
# ...          ...    ...    ...    ...    ...         ...     ...
# 1820  2024-06-21  98.07  98.07  96.40  97.71   4007546.0  -0.355
# 1821  2024-06-22  98.07  98.07  96.40  97.71   4007546.0  -0.355
# 1822  2024-06-23  98.07  98.07  96.40  97.71   4007546.0  -0.355
# 1823  2024-06-24  97.02  97.59  95.72  95.76   3374508.0  -1.260
# 1824  2024-06-25  96.05  98.75  95.18  97.73   2596953.0   1.680
#
#       changePercent     vwap        rsi         adx  standardDeviation  \
# 0          -2.86000  22.9700  58.965646  102.767512           0.898712
# 1          -2.86000  22.9700  58.965646  102.767512           0.898712
# 2          -2.86000  22.9700  58.965646  102.767512           0.898712
# 3          -0.93220  23.4300  62.959665   99.734268           0.877744
# 4           2.23000  23.1500  63.216708   96.577138           0.883491
# ...             ...      ...        ...         ...                ...
# 1820       -0.36708  97.5625  58.150394   16.573959           2.124115
# 1821       -0.36708  97.5625  58.150394   16.573959           2.124115
# 1822       -0.36708  97.5625  58.150394   16.573959           2.124115
# 1823       -1.30000  96.5225  53.264409   16.483934           1.985305
# 1824        1.75000  96.9275  57.178886   16.806322           1.979743
#
#       ratingScore         ds      y
# 0               4 2019-06-28  22.78
# 1               4 2019-06-29  22.78
# 2               4 2019-06-30  22.78
# 3               4 2019-07-01  23.38
# 4               4 2019-07-02  23.42
# ...           ...        ...    ...
# 1820            3 2024-06-21  97.71
# 1821            3 2024-06-22  97.71
# 1822            3 2024-06-23  97.71
# 1823            3 2024-06-24  95.76
# 1824            3 2024-06-25  97.73
#
# [1825 rows x 15 columns]

# %%
m = Prophet()
m.fit(df)
# Out:
# 15:57:54 - cmdstanpy - INFO - Chain [1] start processing
# 15:57:55 - cmdstanpy - INFO - Chain [1] done processing

# %%
future = df.copy()
future = m.make_future_dataframe(periods=14)
future.tail()
# Out:
#              ds
# 1834 2024-07-05
# 1835 2024-07-06
# 1836 2024-07-07
# 1837 2024-07-08
# 1838 2024-07-09

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds       yhat  yhat_lower  yhat_upper
# 1834 2024-07-05  92.403212   83.522850  101.194969
# 1835 2024-07-06  92.498659   83.978939  101.056929
# 1836 2024-07-07  92.601116   84.211062  101.984347
# 1837 2024-07-08  92.731250   84.727378  101.103267
# 1838 2024-07-09  93.015690   84.009350  102.381218

# %%
fig1 = m.plot(forecast)
# Out:
# /Users/anthonydillon/Ironhack/wk8/project/venv-final-project/lib/python3.9/site-packages/prophet/plot.py:72: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# /Users/anthonydillon/Ironhack/wk8/project/venv-final-project/lib/python3.9/site-packages/prophet/plot.py:73: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
fig2 = m.plot_components(forecast)
# Out:
# /Users/anthonydillon/Ironhack/wk8/project/venv-final-project/lib/python3.9/site-packages/prophet/plot.py:228: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# /Users/anthonydillon/Ironhack/wk8/project/venv-final-project/lib/python3.9/site-packages/prophet/plot.py:351: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# /Users/anthonydillon/Ironhack/wk8/project/venv-final-project/lib/python3.9/site-packages/prophet/plot.py:354: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
plot_plotly(m, forecast)
